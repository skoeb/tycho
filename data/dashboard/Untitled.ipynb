# %%
import pandas as pd

df = pd.read_pickle('dashboard_df.pkl')

df
# Out:
#       plant_id_wri datetime_utc  latitude  longitude country primary_fuel  \
# 0       USA0000003   2019-01-01    31.007 -88.010002     USA          Gas
# 1       USA0000003   2019-02-01    31.007 -88.010002     USA          Gas
# 2       USA0000003   2019-03-01    31.007 -88.010002     USA          Gas
# 3       USA0000003   2019-04-01    31.007 -88.010002     USA          Gas
# 4       USA0000003   2019-05-01    31.007 -88.010002     USA          Gas
# ...            ...          ...       ...        ...     ...          ...
# 93739   WRI1026814   2020-03-01    18.455 -66.149000     PRI          Oil
# 93740   WRI1026816   2020-03-01    18.427 -66.104000     PRI          Oil
# 93741   WRI1028009   2020-03-01    18.446 -66.391000     PRI          Gas
# 93742   WRI1028006   2020-03-01    18.143 -65.444000     PRI          Oil
# 93743   WRI1028014   2020-03-01    18.106 -65.825000     PRI          Gas
#
#                       source        type        variable        value
# ...

# %%
import numpy as np
n = df.loc[df['value'] == None]
n
# Out:
# Empty DataFrame
# Columns: [plant_id_wri, datetime_utc, latitude, longitude, country, primary_fuel, source, type, variable, value]
# Index: []
